# %%
# %%capture
# !apt-get update
# !apt-get install libgdal-dev -y
# !apt-get install python-gdal -y
# !apt-get install python-numpy python-scipy -y
# !pip install rasterio
# !pip install fiona
# !pip install geopandas
# !pip install PyCRS
# !pip install -i https://test.pypi.org/simple/ gis-utils-pkg-dillhicks==0.0.76

# %%
from math import sqrt
import torch
import os
from torch import Tensor
from tqdm.autonotebook import tqdm
from torch import nn
from torch.cuda import amp
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data.dataset
import gis_utils.raster as raster
from rasterio.plot import reshape_as_image
import rasterio
from rasterio.plot import reshape_as_raster, reshape_as_image

# %% [markdown]
# # Loading Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/srcnn/srcnn_tiles.zip .
# !unzip srcnn_tiles.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_02_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_02_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_03_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_04_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_05_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_06_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_07_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_08_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_09_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_10_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_11_12.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_01.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_02.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_03.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_04.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_05.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_06.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_07.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_08.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_09.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_10.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_11.tif
#   inflating: train/hr_S2_lap_2020-05_PuertoFalsa_planetscope_optical_12_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_01_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_02_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_03_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_04_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_05_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_06_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_07_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_08_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_09_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_10_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_11_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_12_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_13_24.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_01.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_02.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_03.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_04.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_05.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_06.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_07.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_08.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_09.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_10.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_11.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_12.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_13.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_14.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_15.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_16.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_17.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_18.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_19.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_20.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_21.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_22.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_23.tif
#   inflating: train/hr_S2_psc_2018-05_site11_planetscope_optical_14_24.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_01_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_02_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_03_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_04_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_05_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_06_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_07_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_08_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_09_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_10_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_11_12.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_01.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_02.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_03.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_04.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_05.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_06.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_07.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_08.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_09.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_10.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_11.tif
#   inflating: train/hr_S2_psc_2018-05_site12_planetscope_optical_12_12.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_01.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_02.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_03.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_04.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_05.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_06.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_07.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_08.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_09.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_10.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_11.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_12.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_13.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_01_14.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_02_01.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_02_02.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_02_03.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_02_04.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_02_05.tif
#   inflating: train/hr_S2_psc_2018-05_site13-14_planetscope_optical_02_06.tif
# ...
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_05.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_06.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_07.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_08.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_09.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_10.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_11.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_12.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_13.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_14.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_15.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_16.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_17.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_18.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_19.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_20.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_21.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_22.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_23.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_24.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_25.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_09_26.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_01.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_02.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_03.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_04.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_05.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_06.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_07.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_08.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_09.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_10.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_11.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_12.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_13.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_14.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_15.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_16.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_17.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_18.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_19.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_20.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_21.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_22.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_23.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_24.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_25.tif
#   inflating: train/S2_psc_2018-07_site08_planetscope_optical_10_26.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_01_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_02_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_03_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_04_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_05_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_06_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_07_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_08_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_09.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_10.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_11.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_12.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_13.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_14.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_15.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_16.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_17.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_09_18.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_01.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_02.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_03.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_04.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_05.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_06.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_07.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_08.tif
#   inflating: train/S2_psc_2018-07_site09_planetscope_optical_10_09.tif

# %%
from cv2 import resize
import cv2

def load_data(input_dir):
    target_filenames = [os.path.join(input_dir, x) for x in os.listdir(input_dir) if x.endswith(".tif") and x.startswith("hr_")]

    #Loading LR tiles (getting filenames with "hr_" removed)
    input_filenames = [os.path.join(input_dir, os.path.basename(x)[3:]) for x in target_filenames]
    lr_images = []
    hr_images = []

    lr_meta = []
    hr_meta = []

    transforms = []
    for index in tqdm(range(len(target_filenames))):
        

        lr_image, lr_meta_cur = raster.load_image(input_filenames[index])
        hr_image, hr_meta_cur = raster.load_image(target_filenames[index])
                
        lr_images.append(resize(reshape_as_image(lr_image.read()), (48,48), interpolation = cv2.INTER_AREA))
        hr_images.append(resize(reshape_as_image(hr_image.read()), (48,48), interpolation = cv2.INTER_AREA))
        
        lr_meta.append(lr_meta_cur)
        hr_meta.append(hr_meta_cur)
        transforms.append(lr_image.transform)

    return lr_images, hr_images, lr_meta, hr_meta, target_filenames, transforms

# %% [markdown]
# # Loading Augmented Data

# %%
# !cp /content/drive/MyDrive/srcnn/sr.data .

# %%
import pickle as pkl 
import numpy as np


with open('sr.data', 'rb') as f:
    data = pkl.load(f)

lr_aug = []
hr_aug = []

for image in data:
    hr_aug.append(image[0])
    lr_aug.append(image[1])

hr_aug = np.asarray(hr_aug)
lr_aug = np.asarray(lr_aug)

# %% [markdown]
# # Setting up networks

# %%
def PSNRLoss(y_true, y_pred):

    max_pixel = 1.0
    return (10.0 * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred - y_true), axis=-1)))) / 2.303

# %% [markdown]
# # Custom SR-AE

# %%
import numpy as np

lr_train, hr_train, lr_train_meta, hr_train_meta, train_filenames, train_transforms = load_data("train")
lr_test, hr_test, lr_test_meta, hr_test_meta, test_filenames, test_transforms = load_data("test")

hr_train = np.asarray(hr_train)
lr_train = np.asarray(lr_train)

lr_test = np.asarray(lr_test)
hr_test = np.asarray(hr_test)

# %%
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras import Model, Input, regularizers
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, UpSampling2D, Add, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K


Input_img = Input(shape=(48, 48, 4))  
    
x1 = Conv2D(32, (3, 3), activation='relu', padding='same')(Input_img)
x2 = Conv2D(32, (3, 3), activation='relu', padding='same')(x1)
x3 = MaxPool2D(padding='same')(x2)
x4 = Conv2D(64, (3, 3), activation='relu', padding='same')(x3)
x5 = Conv2D(64, (3, 3), activation='relu', padding='same')(x4)
x6 = MaxPool2D(padding='same')(x5)
encoded = Conv2D(256, (3, 3), activation='relu', padding='same')(x6)
x7 = UpSampling2D()(encoded)
x8 = Conv2D(64, (3, 3), activation='relu', padding='same')(x7)
x9 = Conv2D(64, (3, 3), activation='relu', padding='same')(x8)
x10 = Add()([x5, x9])
x11 = UpSampling2D()(x10)
x12 = Conv2D(32, (3, 3), activation='relu', padding='same')(x11)
x13 = Conv2D(32, (3, 3), activation='relu', padding='same')(x12)
x14 = Add()([x2, x13])

decoded = Conv2D(4, (3, 3), padding='same',activation='relu')(x14)
autoencoder = Model(Input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse', metrics=[PSNRLoss])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


autoencoder = Model(Input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse', metrics=[PSNRLoss])

early_stopper = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=50, verbose=1, mode='min')
model_checkpoint =  ModelCheckpoint('superResolution_checkpoint3.h5', save_best_only = True)

history = autoencoder.fit(lr_train,hr_train,
            epochs=500,
            validation_data=(lr_test, hr_test),
            callbacks=[early_stopper, model_checkpoint])

# %% [markdown]
# # Custom SR-AE Augmented

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


autoencoder_aug = Model(Input_img, decoded)
autoencoder_aug.compile(optimizer='adam', loss='mse', metrics=[PSNRLoss])

early_stopper = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=50, verbose=1, mode='min')
model_checkpoint =  ModelCheckpoint('sr-ae_aug.h5', save_best_only = True)

history = autoencoder_aug.fit(lr_aug,hr_aug,
            epochs=500,
            validation_data=(lr_test, hr_test),
            callbacks=[early_stopper, model_checkpoint])

# %% [markdown]
# # SRCNN

# %%
from tensorflow.keras.layers import Activation
from tensorflow.keras import Sequential

def make_srcnn():

    srcnn = Sequential()
    srcnn.add(Conv2D(64,9,padding='same',input_shape=(48,48,4)))
    srcnn.add(Activation('relu'))
    srcnn.add(Conv2D(32,1,padding='same'))
    srcnn.add(Activation('relu'))
    srcnn.add(Conv2D(4,5,padding='same'))
    return srcnn

srcnn = make_srcnn()
srcnn.compile(optimizer='adam', loss='mean_squared_error', metrics=[PSNRLoss])

# %%
# !pip freeze
# Out:
# absl-py==1.0.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.2.0
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arviz==0.11.4
# astor==0.8.1
# astropy==4.3.1
# astunparse==1.6.3
# atari-py==0.2.9
# atomicwrites==1.4.0
# attrs==21.4.0
# audioread==2.1.9
# autograd==1.3
# Babel==2.9.1
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==4.1.0
# blis==0.4.1
# bokeh==2.3.3
# Bottleneck==1.3.4
# branca==0.4.2
# bs4==0.0.1
# CacheControl==0.12.10
# cached-property==1.5.2
# cachetools==4.2.4
# catalogue==1.0.0
# certifi==2021.10.8
# cffi==1.15.0
# cftime==1.6.0
# chardet==3.0.4
# charset-normalizer==2.0.12
# click==7.1.2
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.9.5
# colorcet==3.0.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.4.0
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cupy-cuda111==9.4.0
# cvxopt==1.2.7
# cvxpy==1.0.31
# cycler==0.11.0
# cymem==2.0.6
# Cython==0.29.28
# daft==0.0.4
# dask==2.12.0
# datascience==0.10.6
# debugpy==1.0.0
# decorator==4.4.2
# defusedxml==0.7.1
# descartes==1.1.0
# dill==0.3.4
# distributed==1.25.3
# dlib @ file:///dlib-19.18.0-cp37-cp37m-linux_x86_64.whl
# dm-tree==0.1.6
# docopt==0.6.2
# docutils==0.17.1
# dopamine-rl==1.0.5
# earthengine-api==0.1.303
# easydict==1.9
# ecos==2.0.10
# editdistance==0.5.3
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz
# entrypoints==0.4
# ephem==4.1.3
# et-xmlfile==1.1.0
# fa2==0.3.5
# fastai==1.0.61
# fastdtw==0.3.4
# fastprogress==1.0.2
# fastrlock==0.8
# fbprophet==0.7.1
# feather-format==0.4.1
# filelock==3.6.0
# firebase-admin==4.4.0
# fix-yahoo-finance==0.0.22
# Flask==1.1.4
# flatbuffers==2.0
# folium==0.8.3
# future==0.16.0
# gast==0.5.3
# GDAL==2.2.2
# gdown==4.2.2
# gensim==3.6.0
# geographiclib==1.52
# geopy==1.17.0
# gin-config==0.5.0
# glob2==0.7
# google==2.0.3
# google-api-core==1.26.3
# google-api-python-client==1.12.11
# google-auth==1.35.0
# google-auth-httplib2==0.0.4
# google-auth-oauthlib==0.4.6
# google-cloud-bigquery==1.21.0
# google-cloud-bigquery-storage==1.1.0
# google-cloud-core==1.0.3
# google-cloud-datastore==1.8.0
# google-cloud-firestore==1.7.0
# google-cloud-language==1.2.0
# google-cloud-storage==1.18.1
# google-cloud-translate==1.5.0
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz
# google-pasta==0.2.0
# google-resumable-media==0.4.1
# googleapis-common-protos==1.56.0
# googledrivedownloader==0.4
# graphviz==0.10.1
# greenlet==1.1.2
# grpcio==1.44.0
# gspread==3.4.2
# gspread-dataframe==3.0.8
# gym==0.17.3
# h5py==3.1.0
# HeapDict==1.0.1
# hijri-converter==2.2.3
# holidays==0.10.5.2
# holoviews==1.14.8
# html5lib==1.0.1
# httpimport==0.5.18
# httplib2==0.17.4
# httplib2shim==0.0.3
# humanize==0.5.1
# hyperopt==0.1.2
# ideep4py==2.0.0.post3
# idna==2.10
# imageio==2.4.1
# imagesize==1.3.0
# imbalanced-learn==0.8.1
# imblearn==0.0
# imgaug==0.2.9
# importlib-metadata==4.11.3
# importlib-resources==5.4.0
# imutils==0.5.4
# inflect==2.1.0
# iniconfig==1.1.1
# intel-openmp==2022.0.2
# intervaltree==2.1.0
# ipykernel==4.10.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# ipywidgets==7.7.0
# itsdangerous==1.1.0
# jax==0.3.4
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.3.2+cuda11.cudnn805-cp37-none-manylinux2010_x86_64.whl
# jedi==0.18.1
# jieba==0.42.1
# Jinja2==2.11.3
# joblib==1.1.0
# jpeg4py==0.1.4
# jsonschema==4.3.3
# jupyter==1.0.0
# jupyter-client==5.3.5
# jupyter-console==5.2.0
# jupyter-core==4.9.2
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.1.0
# kaggle==1.5.12
# kapre==0.3.7
# keras==2.8.0
# Keras-Preprocessing==1.1.2
# keras-vis==0.4.1
# kiwisolver==1.4.0
# korean-lunar-calendar==0.2.1
# libclang==13.0.0
# librosa==0.8.1
# lightgbm==2.2.3
# llvmlite==0.34.0
# lmdb==0.99
# LunarCalendar==0.0.9
# lxml==4.2.6
# Markdown==3.3.6
# MarkupSafe==2.0.1
# matplotlib==3.2.2
# matplotlib-inline==0.1.3
# matplotlib-venn==0.11.6
# missingno==0.5.1
# mistune==0.8.4
# mizani==0.6.0
# mkl==2019.0
# mlxtend==0.14.0
# more-itertools==8.12.0
# moviepy==0.2.3.5
# mpmath==1.2.1
# msgpack==1.0.3
# multiprocess==0.70.12.2
# multitasking==0.0.10
# murmurhash==1.0.6
# music21==5.5.0
# natsort==5.5.0
# nbclient==0.5.13
# nbconvert==5.6.1
# nbformat==5.2.0
# nest-asyncio==1.5.4
# netCDF4==1.5.8
# networkx==2.6.3
# nibabel==3.0.2
# nltk==3.2.5
# notebook==5.3.1
# numba==0.51.2
# numexpr==2.8.1
# numpy==1.21.5
# nvidia-ml-py3==7.352.0
# oauth2client==4.1.3
# oauthlib==3.2.0
# okgrade==0.4.3
# opencv-contrib-python==4.1.2.30
# opencv-python==4.1.2.30
# openpyxl==3.0.9
# opt-einsum==3.3.0
# osqp==0.6.2.post0
# packaging==21.3
# palettable==3.3.0
# pandas==1.3.5
# pandas-datareader==0.9.0
# pandas-gbq==0.13.3
# pandas-profiling==1.4.1
# pandocfilters==1.5.0
# panel==0.12.1
# param==1.12.0
# parso==0.8.3
# pathlib==1.0.1
# patsy==0.5.2
# pep517==0.12.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.1.2
# pip-tools==6.2.0
# plac==1.1.3
# plotly==5.5.0
# plotnine==0.6.0
# pluggy==0.7.1
# pooch==1.6.0
# portpicker==1.3.9
# prefetch-generator==1.0.1
# preshed==3.0.6
# prettytable==3.2.0
# progressbar2==3.38.0
# prometheus-client==0.13.1
# promise==2.3
# prompt-toolkit==1.0.18
# protobuf==3.17.3
# psutil==5.4.8
# psycopg2==2.7.6.1
# ptyprocess==0.7.0
# py==1.11.0
# pyarrow==6.0.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.4
# pycparser==2.21
# pyct==0.4.8
# pydata-google-auth==1.4.0
# pydot==1.3.0
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyemd==0.5.1
# pyerfa==2.0.0.1
# pyglet==1.5.0
# Pygments==2.6.1
# pygobject==3.26.1
# pymc3==3.11.4
# PyMeeus==0.5.11
# pymongo==4.0.2
# pymystem3==0.2.0
# PyOpenGL==3.1.6
# pyparsing==3.0.7
# pyrsistent==0.18.1
# pysndfile==1.3.8
# PySocks==1.7.1
# pystan==2.19.1.1
# pytest==3.6.4
# python-apt==0.0.0
# python-chess==0.23.11
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==6.1.1
# python-utils==3.1.0
# pytz==2018.9
# pyviz-comms==2.1.0
# PyWavelets==1.3.0
# PyYAML==3.13
# pyzmq==22.3.0
# qdldl==0.1.5.post0
# qtconsole==5.2.2
# QtPy==2.0.1
# regex==2019.12.20
# requests==2.23.0
# requests-oauthlib==1.3.1
# resampy==0.2.2
# rpy2==3.4.5
# rsa==4.8
# scikit-image==0.18.3
# scikit-learn==1.0.2
# scipy==1.4.1
# screen-resolution-extra==0.0.0
# scs==3.2.0
# seaborn==0.11.2
# semver==2.13.0
# Send2Trash==1.8.0
# setuptools-git==1.2
# Shapely==1.8.1.post1
# simplegeneric==0.8.1
# six==1.15.0
# sklearn==0.0
# sklearn-pandas==1.8.0
# smart-open==5.2.1
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# SoundFile==0.10.3.post1
# soupsieve==2.3.1
# spacy==2.2.4
# Sphinx==1.8.6
# sphinxcontrib-serializinghtml==1.1.5
# sphinxcontrib-websupport==1.2.4
# SQLAlchemy==1.4.32
# sqlparse==0.4.2
# srsly==1.0.5
# statsmodels==0.10.2
# sympy==1.7.1
# tables==3.7.0
# tabulate==0.8.9
# tblib==1.7.0
# tenacity==8.0.1
# tensorboard==2.8.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.1
# tensorflow @ file:///tensorflow-2.8.0-cp37-cp37m-linux_x86_64.whl
# tensorflow-datasets==4.0.1
# tensorflow-estimator==2.8.0
# tensorflow-gcs-config==2.8.0
# tensorflow-hub==0.12.0
# tensorflow-io-gcs-filesystem==0.24.0
# tensorflow-metadata==1.7.0
# tensorflow-probability==0.16.0
# termcolor==1.1.0
# terminado==0.13.3
# testpath==0.6.0
# text-unidecode==1.3
# textblob==0.15.3
# Theano-PyMC==1.1.2
# thinc==7.4.0
# threadpoolctl==3.1.0
# tifffile==2021.11.2
# tomli==2.0.1
# toolz==0.11.2
# torch @ https://download.pytorch.org/whl/cu111/torch-1.10.0%2Bcu111-cp37-cp37m-linux_x86_64.whl
# torchaudio @ https://download.pytorch.org/whl/cu111/torchaudio-0.10.0%2Bcu111-cp37-cp37m-linux_x86_64.whl
# torchsummary==1.5.1
# torchtext==0.11.0
# torchvision @ https://download.pytorch.org/whl/cu111/torchvision-0.11.1%2Bcu111-cp37-cp37m-linux_x86_64.whl
# tornado==5.1.1
# tqdm==4.63.0
# traitlets==5.1.1
# tweepy==3.10.0
# typeguard==2.7.1
# typing-extensions==3.10.0.2
# tzlocal==1.5.1
# uritemplate==3.0.1
# urllib3==1.24.3
# vega-datasets==0.9.0
# wasabi==0.9.0
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==1.0.1
# widgetsnbextension==3.6.0
# wordcloud==1.5.0
# wrapt==1.14.0
# xarray==0.18.2
# xgboost==0.90
# xkit==0.0.0
# xlrd==1.1.0
# xlwt==1.3.0
# yellowbrick==1.4
# zict==2.1.0
# zipp==3.7.0

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopper = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=50, verbose=1, mode='min')
model_checkpoint =  ModelCheckpoint('srcnn.h5', save_best_only = True)

history = srcnn.fit(lr_train,hr_train,
            epochs=500,
            validation_data=(lr_test, hr_test),
            callbacks=[early_stopper, model_checkpoint])
# Out:
# Epoch 1/500
# 85/85 [==============================] - 3s 21ms/step - loss: 0.0019 - PSNRLoss: 31.7722 - val_loss: 0.0015 - val_PSNRLoss: 30.9663
# Epoch 2/500
# 85/85 [==============================] - 1s 16ms/step - loss: 7.0164e-04 - PSNRLoss: 35.5631 - val_loss: 8.0305e-04 - val_PSNRLoss: 35.1414
# Epoch 3/500
# 85/85 [==============================] - 1s 15ms/step - loss: 6.2792e-04 - PSNRLoss: 36.1923 - val_loss: 9.7836e-04 - val_PSNRLoss: 33.5472
# Epoch 4/500
# 85/85 [==============================] - 1s 16ms/step - loss: 5.3970e-04 - PSNRLoss: 37.2747 - val_loss: 6.3592e-04 - val_PSNRLoss: 36.1242
# Epoch 5/500
# 85/85 [==============================] - 1s 15ms/step - loss: 5.3896e-04 - PSNRLoss: 37.1151 - val_loss: 7.1119e-04 - val_PSNRLoss: 36.1325
# Epoch 6/500
# 85/85 [==============================] - 1s 15ms/step - loss: 5.1346e-04 - PSNRLoss: 37.5939 - val_loss: 0.0012 - val_PSNRLoss: 32.5148
# Epoch 7/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.8862e-04 - PSNRLoss: 37.8173 - val_loss: 7.5172e-04 - val_PSNRLoss: 35.5759
# Epoch 8/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.4986e-04 - PSNRLoss: 38.4503 - val_loss: 6.6795e-04 - val_PSNRLoss: 36.4984
# Epoch 9/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.4075e-04 - PSNRLoss: 38.4659 - val_loss: 6.5004e-04 - val_PSNRLoss: 36.8309
# Epoch 10/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.5849e-04 - PSNRLoss: 38.1687 - val_loss: 6.8867e-04 - val_PSNRLoss: 36.0054
# Epoch 11/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.4581e-04 - PSNRLoss: 38.2140 - val_loss: 6.1884e-04 - val_PSNRLoss: 36.8631
# Epoch 12/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.4732e-04 - PSNRLoss: 38.1020 - val_loss: 5.5999e-04 - val_PSNRLoss: 37.4137
# Epoch 13/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.7806e-04 - PSNRLoss: 37.7906 - val_loss: 6.0863e-04 - val_PSNRLoss: 37.2953
# Epoch 14/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.0152e-04 - PSNRLoss: 38.9897 - val_loss: 8.1737e-04 - val_PSNRLoss: 34.5822
# Epoch 15/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.4257e-04 - PSNRLoss: 38.0959 - val_loss: 6.1515e-04 - val_PSNRLoss: 36.6776
# Epoch 16/500
# 85/85 [==============================] - 1s 16ms/step - loss: 4.1781e-04 - PSNRLoss: 38.4876 - val_loss: 6.6905e-04 - val_PSNRLoss: 35.8709
# Epoch 17/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.9370e-04 - PSNRLoss: 39.0644 - val_loss: 0.0011 - val_PSNRLoss: 33.7786
# Epoch 18/500
# 85/85 [==============================] - 1s 15ms/step - loss: 4.7324e-04 - PSNRLoss: 37.7091 - val_loss: 5.5768e-04 - val_PSNRLoss: 36.5484
# Epoch 19/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.6636e-04 - PSNRLoss: 39.5336 - val_loss: 5.8637e-04 - val_PSNRLoss: 37.4201
# Epoch 20/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.9484e-04 - PSNRLoss: 38.8410 - val_loss: 6.6589e-04 - val_PSNRLoss: 35.3387
# Epoch 21/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.7558e-04 - PSNRLoss: 39.1636 - val_loss: 7.6103e-04 - val_PSNRLoss: 35.6513
# Epoch 22/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.8490e-04 - PSNRLoss: 39.0854 - val_loss: 9.6853e-04 - val_PSNRLoss: 33.6089
# Epoch 23/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.7026e-04 - PSNRLoss: 39.0592 - val_loss: 5.5651e-04 - val_PSNRLoss: 37.0018
# Epoch 24/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.8431e-04 - PSNRLoss: 38.7745 - val_loss: 6.2819e-04 - val_PSNRLoss: 36.8147
# Epoch 25/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.5635e-04 - PSNRLoss: 39.5317 - val_loss: 5.8388e-04 - val_PSNRLoss: 37.1292
# Epoch 26/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.4813e-04 - PSNRLoss: 39.6609 - val_loss: 7.4027e-04 - val_PSNRLoss: 35.5125
# Epoch 27/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.6121e-04 - PSNRLoss: 39.2772 - val_loss: 6.6957e-04 - val_PSNRLoss: 35.9645
# Epoch 28/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.5893e-04 - PSNRLoss: 39.2325 - val_loss: 8.5673e-04 - val_PSNRLoss: 34.5984
# Epoch 29/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.6815e-04 - PSNRLoss: 39.0758 - val_loss: 6.3004e-04 - val_PSNRLoss: 35.6347
# Epoch 30/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.5449e-04 - PSNRLoss: 39.2700 - val_loss: 8.4339e-04 - val_PSNRLoss: 34.4700
# Epoch 31/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.6681e-04 - PSNRLoss: 39.1373 - val_loss: 7.5897e-04 - val_PSNRLoss: 35.5653
# Epoch 32/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.8421e-04 - PSNRLoss: 38.7803 - val_loss: 5.7069e-04 - val_PSNRLoss: 36.8657
# Epoch 33/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.3894e-04 - PSNRLoss: 39.7670 - val_loss: 5.4297e-04 - val_PSNRLoss: 36.5615
# Epoch 34/500
# 85/85 [==============================] - 1s 16ms/step - loss: 3.7838e-04 - PSNRLoss: 38.8379 - val_loss: 5.5501e-04 - val_PSNRLoss: 36.7094
# Epoch 35/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.3884e-04 - PSNRLoss: 39.5797 - val_loss: 5.7109e-04 - val_PSNRLoss: 37.2643
# Epoch 36/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.3542e-04 - PSNRLoss: 39.6289 - val_loss: 5.4151e-04 - val_PSNRLoss: 38.1209
# Epoch 37/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.7275e-04 - PSNRLoss: 38.8689 - val_loss: 5.7396e-04 - val_PSNRLoss: 37.6301
# Epoch 38/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.4988e-04 - PSNRLoss: 39.3532 - val_loss: 6.0170e-04 - val_PSNRLoss: 36.9394
# Epoch 39/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.4059e-04 - PSNRLoss: 39.5337 - val_loss: 5.6071e-04 - val_PSNRLoss: 37.7413
# Epoch 40/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.3222e-04 - PSNRLoss: 39.6715 - val_loss: 7.0510e-04 - val_PSNRLoss: 36.0354
# Epoch 41/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.4645e-04 - PSNRLoss: 39.2324 - val_loss: 5.7494e-04 - val_PSNRLoss: 37.7222
# Epoch 42/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.6951e-04 - PSNRLoss: 38.9297 - val_loss: 6.9110e-04 - val_PSNRLoss: 35.6086
# Epoch 43/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.4456e-04 - PSNRLoss: 39.3633 - val_loss: 5.6537e-04 - val_PSNRLoss: 36.9598
# Epoch 44/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.2022e-04 - PSNRLoss: 39.9251 - val_loss: 5.3188e-04 - val_PSNRLoss: 37.7470
# Epoch 45/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.2217e-04 - PSNRLoss: 39.8613 - val_loss: 6.9583e-04 - val_PSNRLoss: 36.2486
# Epoch 46/500
# 85/85 [==============================] - 1s 16ms/step - loss: 3.2781e-04 - PSNRLoss: 39.6320 - val_loss: 5.5134e-04 - val_PSNRLoss: 37.2982
# Epoch 47/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.3044e-04 - PSNRLoss: 39.5033 - val_loss: 7.6493e-04 - val_PSNRLoss: 35.4512
# Epoch 48/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.1917e-04 - PSNRLoss: 39.8236 - val_loss: 5.6008e-04 - val_PSNRLoss: 36.6724
# Epoch 49/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.2506e-04 - PSNRLoss: 39.7033 - val_loss: 6.6734e-04 - val_PSNRLoss: 35.8176
# Epoch 50/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.3375e-04 - PSNRLoss: 39.4658 - val_loss: 6.0697e-04 - val_PSNRLoss: 36.5227
# Epoch 51/500
# 85/85 [==============================] - 1s 15ms/step - loss: 3.4321e-04 - PSNRLoss: 39.2499 - val_loss: 7.8602e-04 - val_PSNRLoss: 35.4525
# Epoch 00051: early stopping

# %% [markdown]
# # SRCNN Augmented

# %%
srcnn_aug = make_srcnn()
srcnn_aug.compile(optimizer='adam', loss='mean_squared_error', metrics=[PSNRLoss])

early_stopper = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=50, verbose=1, mode='min')
model_checkpoint =  ModelCheckpoint('srcnn_aug.h5', save_best_only = True)

history = srcnn_aug.fit(lr_aug, hr_aug,
            epochs=500,
            validation_data=(lr_test, hr_test),
            callbacks=[early_stopper, model_checkpoint])
# Out:
# Epoch 1/500
# 337/337 [==============================] - 6s 15ms/step - loss: 0.0010 - PSNRLoss: 34.2891 - val_loss: 0.0011 - val_PSNRLoss: 33.5082
# Epoch 2/500
# 337/337 [==============================] - 5s 14ms/step - loss: 6.7747e-04 - PSNRLoss: 35.8866 - val_loss: 8.8210e-04 - val_PSNRLoss: 34.9069
# Epoch 3/500
# 337/337 [==============================] - 5s 14ms/step - loss: 6.5675e-04 - PSNRLoss: 36.0552 - val_loss: 0.0012 - val_PSNRLoss: 33.0878
# Epoch 4/500
# 337/337 [==============================] - 5s 14ms/step - loss: 6.3097e-04 - PSNRLoss: 36.2164 - val_loss: 9.6299e-04 - val_PSNRLoss: 34.6360
# Epoch 5/500
# 337/337 [==============================] - 5s 14ms/step - loss: 6.2043e-04 - PSNRLoss: 36.2426 - val_loss: 8.2861e-04 - val_PSNRLoss: 35.3977
# Epoch 6/500
# 337/337 [==============================] - 5s 14ms/step - loss: 6.1177e-04 - PSNRLoss: 36.3293 - val_loss: 9.6995e-04 - val_PSNRLoss: 33.9212
# Epoch 7/500
# 337/337 [==============================] - 5s 14ms/step - loss: 6.0305e-04 - PSNRLoss: 36.3688 - val_loss: 8.8913e-04 - val_PSNRLoss: 35.1088
# Epoch 8/500
# 337/337 [==============================] - 5s 14ms/step - loss: 6.1053e-04 - PSNRLoss: 36.3535 - val_loss: 7.9107e-04 - val_PSNRLoss: 35.8161
# Epoch 9/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.8648e-04 - PSNRLoss: 36.5375 - val_loss: 8.8776e-04 - val_PSNRLoss: 34.9768
# Epoch 10/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.7945e-04 - PSNRLoss: 36.6148 - val_loss: 0.0010 - val_PSNRLoss: 33.8512
# Epoch 11/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.9150e-04 - PSNRLoss: 36.4649 - val_loss: 9.1794e-04 - val_PSNRLoss: 34.9969
# Epoch 12/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.8254e-04 - PSNRLoss: 36.5720 - val_loss: 8.4388e-04 - val_PSNRLoss: 35.5507
# Epoch 13/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.7714e-04 - PSNRLoss: 36.6849 - val_loss: 7.9692e-04 - val_PSNRLoss: 35.9372
# Epoch 14/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.6702e-04 - PSNRLoss: 36.6879 - val_loss: 0.0011 - val_PSNRLoss: 33.7555
# Epoch 15/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.7961e-04 - PSNRLoss: 36.5647 - val_loss: 8.1443e-04 - val_PSNRLoss: 35.7214
# Epoch 16/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.7857e-04 - PSNRLoss: 36.5759 - val_loss: 9.1240e-04 - val_PSNRLoss: 34.9694
# Epoch 17/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.6105e-04 - PSNRLoss: 36.7699 - val_loss: 9.1366e-04 - val_PSNRLoss: 34.9039
# Epoch 18/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.5754e-04 - PSNRLoss: 36.7719 - val_loss: 9.7921e-04 - val_PSNRLoss: 34.8718
# Epoch 19/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.4914e-04 - PSNRLoss: 36.8332 - val_loss: 0.0010 - val_PSNRLoss: 34.4961
# Epoch 20/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.5206e-04 - PSNRLoss: 36.8076 - val_loss: 9.4273e-04 - val_PSNRLoss: 35.0069
# Epoch 21/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.4128e-04 - PSNRLoss: 36.8926 - val_loss: 9.1376e-04 - val_PSNRLoss: 35.3460
# Epoch 22/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.5488e-04 - PSNRLoss: 36.7567 - val_loss: 8.9588e-04 - val_PSNRLoss: 35.4129
# Epoch 23/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.4954e-04 - PSNRLoss: 36.7836 - val_loss: 8.7004e-04 - val_PSNRLoss: 35.7391
# Epoch 24/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.3352e-04 - PSNRLoss: 36.9495 - val_loss: 7.7948e-04 - val_PSNRLoss: 36.1810
# Epoch 25/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.4427e-04 - PSNRLoss: 36.8593 - val_loss: 9.2383e-04 - val_PSNRLoss: 34.8325
# Epoch 26/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.5710e-04 - PSNRLoss: 36.7313 - val_loss: 8.3663e-04 - val_PSNRLoss: 35.5526
# Epoch 27/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.4611e-04 - PSNRLoss: 36.8873 - val_loss: 8.6032e-04 - val_PSNRLoss: 35.8906
# Epoch 28/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.2889e-04 - PSNRLoss: 37.0232 - val_loss: 9.0439e-04 - val_PSNRLoss: 35.5420
# Epoch 29/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.3270e-04 - PSNRLoss: 36.9783 - val_loss: 9.4131e-04 - val_PSNRLoss: 34.8970
# Epoch 30/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.2848e-04 - PSNRLoss: 37.0002 - val_loss: 9.7408e-04 - val_PSNRLoss: 35.0703
# Epoch 31/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.1431e-04 - PSNRLoss: 37.1354 - val_loss: 9.4532e-04 - val_PSNRLoss: 35.6273
# Epoch 32/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.2174e-04 - PSNRLoss: 37.0522 - val_loss: 9.2619e-04 - val_PSNRLoss: 34.9915
# Epoch 33/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.2150e-04 - PSNRLoss: 37.0786 - val_loss: 9.8786e-04 - val_PSNRLoss: 35.1534
# Epoch 34/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.1546e-04 - PSNRLoss: 37.1047 - val_loss: 0.0012 - val_PSNRLoss: 33.7842
# Epoch 35/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.3558e-04 - PSNRLoss: 36.9805 - val_loss: 0.0010 - val_PSNRLoss: 34.3644
# Epoch 36/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.1867e-04 - PSNRLoss: 37.0915 - val_loss: 8.4893e-04 - val_PSNRLoss: 36.0045
# Epoch 37/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.1056e-04 - PSNRLoss: 37.1864 - val_loss: 0.0010 - val_PSNRLoss: 34.7908
# Epoch 38/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.1014e-04 - PSNRLoss: 37.1441 - val_loss: 9.5160e-04 - val_PSNRLoss: 35.2070
# Epoch 39/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.0859e-04 - PSNRLoss: 37.1615 - val_loss: 9.8960e-04 - val_PSNRLoss: 34.9889
# Epoch 40/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.2327e-04 - PSNRLoss: 37.0650 - val_loss: 9.0277e-04 - val_PSNRLoss: 36.0251
# Epoch 41/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.0273e-04 - PSNRLoss: 37.2041 - val_loss: 9.8659e-04 - val_PSNRLoss: 35.0271
# Epoch 42/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.0266e-04 - PSNRLoss: 37.1983 - val_loss: 7.8143e-04 - val_PSNRLoss: 36.2311
# Epoch 43/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.0258e-04 - PSNRLoss: 37.1928 - val_loss: 9.0191e-04 - val_PSNRLoss: 35.8264
# Epoch 44/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.0145e-04 - PSNRLoss: 37.2079 - val_loss: 8.4851e-04 - val_PSNRLoss: 35.8119
# Epoch 45/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.0640e-04 - PSNRLoss: 37.1232 - val_loss: 0.0010 - val_PSNRLoss: 34.9091
# Epoch 46/500
# 337/337 [==============================] - 5s 14ms/step - loss: 4.9610e-04 - PSNRLoss: 37.2456 - val_loss: 9.8559e-04 - val_PSNRLoss: 35.1726
# Epoch 47/500
# 337/337 [==============================] - 5s 14ms/step - loss: 4.9746e-04 - PSNRLoss: 37.2268 - val_loss: 9.7174e-04 - val_PSNRLoss: 35.5229
# Epoch 48/500
# 337/337 [==============================] - 5s 14ms/step - loss: 5.0024e-04 - PSNRLoss: 37.1913 - val_loss: 0.0010 - val_PSNRLoss: 35.2601
# Epoch 49/500
# 337/337 [==============================] - 5s 14ms/step - loss: 4.9095e-04 - PSNRLoss: 37.2991 - val_loss: 0.0011 - val_PSNRLoss: 34.6307
# Epoch 50/500
# 337/337 [==============================] - 5s 14ms/step - loss: 4.8925e-04 - PSNRLoss: 37.2896 - val_loss: 9.2718e-04 - val_PSNRLoss: 35.8067
# Epoch 51/500
# 337/337 [==============================] - 5s 14ms/step - loss: 4.8876e-04 - PSNRLoss: 37.3235 - val_loss: 9.2565e-04 - val_PSNRLoss: 35.7066
# Epoch 00051: early stopping

# %% [markdown]
# # Visualizations

# %%
import matplotlib.pyplot as plt

resolved_data = autoencoder.predict(lr_test)

print(resolved_data.shape)

n = 10  # how many digits we will display
plt.figure(3)
plt.figure(figsize=(20, 10))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(resolved_data[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display hidden layer representation
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(lr_test[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    print(lr_test[i,:,:,0:3].shape)
    
    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n + n)
    plt.imshow(hr_test[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# (674, 48, 48, 4)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %%
resolved_data = autoencoder_aug.predict(lr_test)

print(resolved_data.shape)

n = 10  # how many digits we will display
plt.figure(3)
plt.figure(figsize=(20, 10))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(resolved_data[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display hidden layer representation
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(lr_test[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    print(lr_test[i,:,:,0:3].shape)
    
    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n + n)
    plt.imshow(hr_test[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# (674, 48, 48, 4)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %%
resolved_data = srcnn.predict(lr_test)

print(resolved_data.shape)

n = 10  # how many digits we will display
plt.figure(3)
plt.figure(figsize=(20, 10))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(resolved_data[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display hidden layer representation
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(lr_test[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    print(lr_test[i,:,:,0:3].shape)
    
    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n + n)
    plt.imshow(hr_test[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# (674, 48, 48, 4)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %%
resolved_data = srcnn_aug.predict(lr_test)

print(resolved_data.shape)

n = 10  # how many digits we will display
plt.figure(3)
plt.figure(figsize=(20, 10))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(resolved_data[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display hidden layer representation
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(lr_test[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    print(lr_test[i,:,:,0:3].shape)
    
    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n + n)
    plt.imshow(hr_test[i,:,:,0:3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# (674, 48, 48, 4)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %% [markdown]
# # Making mosaic of the super-resolved tiles

# %%
# !mkdir sr_tiles
from fiona.crs import from_epsg
import rasterio
from rasterio.plot import reshape_as_raster, reshape_as_image

sr_test = autoencoder.predict(lr_test)
sr_train = autoencoder.predict(lr_train)


for i in tqdm(range(len(lr_test))):
    image = sr_test[i,:,:,:]
    meta = hr_test_meta[i]
    filename = test_filenames[i]
    transform = test_transforms[i]

    out_meta = meta.copy()
    out_meta.update({"driver": "GTiff","height": image.shape[0], "width": image.shape[1], "transform": transform})
    outpath = os.path.join("sr_tiles", "sr" + os.path.basename(filename))
    with rasterio.open(outpath, 'w', **out_meta) as outds:
        outds.write(reshape_as_raster(image))


for i in tqdm(range(len(lr_train))):
    image = sr_train[i,:,:,:]
    meta = hr_train_meta[i]
    filename = train_filenames[i]
    transform = train_transforms[i]
    out_meta = meta.copy()
    #fix shape
    out_meta.update({"driver": "GTiff","height": image.shape[0], "width": image.shape[1], "transform": transform})
    outpath = os.path.join("sr_tiles", "sr" + os.path.basename(filename))
    with rasterio.open(outpath, 'w', **out_meta) as outds:
        outds.write(reshape_as_raster(image))
# Out:
#   0%|          | 0/674 [00:00<?, ?it/s]
#   0%|          | 0/2694 [00:00<?, ?it/s]

# %%
# !unzip test.zip -d testing
# Out:
# unzip:  cannot find or open test.zip, test.zip.zip or test.zip.ZIP.

# %%
# !rm -rf testing

# %%
from cv2 import resize
import cv2

def load_unresolved(input_dir):
    target_filenames = [os.path.join(input_dir, x) for x in os.listdir(input_dir) if x.endswith(".tif")]
    lr_images = []

    lr_meta = []

    bounds = []
    for index in tqdm(range(len(target_filenames))):
        

        lr_image, lr_meta_cur = raster.load_image(target_filenames[index])

                
        lr_images.append(resize(reshape_as_image(lr_image.read()), (48,48), interpolation = cv2.INTER_AREA))
        
        lr_meta.append(lr_meta_cur)
        bounds.append(lr_image.bounds)

    return lr_images, lr_meta, target_filenames, bounds

# %%
s1_images, s1_meta, s1_files, s1_bounds = load_unresolved("testing")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-0b567f9fdf53> in <module>()
# ----> 1 s1_images, s1_meta, s1_files, s1_bounds = load_unresolved("testing")
#
# <ipython-input-23-07d6ea399982> in load_unresolved(input_dir)
#       3
#       4 def load_unresolved(input_dir):
# ----> 5     target_filenames = [os.path.join(input_dir, x) for x in os.listdir(input_dir) if x.endswith(".tif")]
#       6     lr_images = []
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testing'

# %%
from rasterio.transform import from_bounds


s1_images = np.asarray(s1_images)
s1_resolved = autoencoder.predict(s1_images)

for i in tqdm(range(len(s1_files))):
    image = s1_resolved[i,:,:,:]
    meta = s1_meta[i]
    filename = s1_files[i]
    bounds = s1_bounds[i]
    out_meta = meta.copy()

    transform = from_bounds(bounds.left, bounds.bottom, bounds.right, bounds.top, image.shape[1], image.shape[0])
    #fix shape
    out_meta.update({"driver": "GTiff","height": image.shape[0], "width": image.shape[1], "transform": transform})
    outpath = os.path.join("sr_testing", "sr" + os.path.basename(filename))
    with rasterio.open(outpath, 'w', **out_meta) as outds:
        outds.write(reshape_as_raster(image))

# %%
s1_images = np.asarray(s1_images)
s1_resolved = srcnn.predict(s1_images)

for i in tqdm(range(len(s1_files))):
    image = s1_resolved[i,:,:,:]
    meta = s1_meta[i]
    filename = s1_files[i]
    bounds = s1_bounds[i]
    out_meta = meta.copy()
    #fix shape

    transform = from_bounds(bounds.left, bounds.bottom, bounds.right, bounds.top, image.shape[1], image.shape[0])

    out_meta.update({"driver": "GTiff","height": image.shape[0], "width": image.shape[1], "transform": transform})
    outpath = os.path.join("sr_testing_2", "sr" + os.path.basename(filename))
    with rasterio.open(outpath, 'w', **out_meta) as outds:
        outds.write(reshape_as_raster(image))

# %%
from rasterio.merge import merge
from rasterio.plot import show
import rasterio

src_files_to_mosaic = []

for fp in os.listdir("testing"):
    src = rasterio.open(os.path.join("testing", fp))
    src_files_to_mosaic.append(src)

mosaic, out_trans = merge(src_files_to_mosaic)
print(mosaic.shape)
plt.figure(figsize=(20, 20))
show(mosaic[0:3,:,:])

# %%
from rasterio.merge import merge
from rasterio.plot import show

src_files_to_mosaic = []

for fp in os.listdir("sr_testing"):
    src = rasterio.open(os.path.join("sr_testing", fp))
    src_files_to_mosaic.append(src)

mosaic, out_trans = merge(src_files_to_mosaic)
print(mosaic.shape)
plt.figure(figsize=(20, 20))
show(mosaic[0:3,:,:])

# %%
from rasterio.merge import merge
from rasterio.plot import show

src_files_to_mosaic = []

for fp in os.listdir("sr_testing_2"):
    src = rasterio.open(os.path.join("sr_testing_2", fp))
    src_files_to_mosaic.append(src)

mosaic, out_trans = merge(src_files_to_mosaic)
print(mosaic.shape)
plt.figure(figsize=(10, 10))

show(mosaic[0:3,:,:])
