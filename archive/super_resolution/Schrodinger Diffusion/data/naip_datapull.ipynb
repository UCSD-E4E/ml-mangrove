# %%
# imports
import json
import requests
from getpass import getpass
import sys
import time
import argparse
import os
import pandas as pd
import warnings
import threading
import re
import datetime
warnings.filterwarnings("ignore")

# %%
path = "/home/a.jajodia.229/mangrove/mount/Machine Learning Datasets/NAIP Data" # Fill a valid path to save the downloaded files
maxthreads = 5 # Threads count for downloads
sema = threading.Semaphore(value=maxthreads)
label = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") # Customized label using date time
threads = []

# %%
# Send http request
def sendRequest(url, data, apiKey = None, exitIfNoResponse = True):
    """
    Send a request to an M2M endpoint and returns the parsed JSON response.

    Parameters:
    endpoint_url (str): The URL of the M2M endpoint
    payload (dict): The payload to be sent with the request

    Returns:
    dict: Parsed JSON response
    """  
    
    json_data = json.dumps(data)
    
    if apiKey == None:
        response = requests.post(url, json_data)
    else:
        headers = {'X-Auth-Token': apiKey}              
        response = requests.post(url, json_data, headers = headers)  
    
    try:
      httpStatusCode = response.status_code 
      if response == None:
          print("No output from service")
          if exitIfNoResponse: sys.exit()
          else: return False
      output = json.loads(response.text)
      if output['errorCode'] != None:
          print(output['errorCode'], "- ", output['errorMessage'])
          if exitIfNoResponse: sys.exit()
          else: return False
      if  httpStatusCode == 404:
          print("404 Not Found")
          if exitIfNoResponse: sys.exit()
          else: return False
      elif httpStatusCode == 401: 
          print("401 Unauthorized")
          if exitIfNoResponse: sys.exit()
          else: return False
      elif httpStatusCode == 400:
          print("Error Code", httpStatusCode)
          if exitIfNoResponse: sys.exit()
          else: return False
    except Exception as e: 
          response.close()
          print(e)
          if exitIfNoResponse: sys.exit()
          else: return False
    response.close()
    
    return output['data']

# %%
def prompt_ERS_login(serviceURL):
    print("Logging in...\n")

    p = ['Enter EROS Registration System (ERS) Username: ', 'Enter ERS Account Token: ']

    # Use requests.post() to make the login request
    response = requests.post(f"{serviceUrl}login-token", json={'username': getpass(prompt=p[0]), 'token': getpass(prompt=p[1])})

    # Check for successful response
    if response.status_code == 200:  
        apiKey = response.json()['data']
        print('\nLogin Successful, API Key Received!')
        headers = {'X-Auth-Token': apiKey}
        return apiKey
    else:
        print("\nLogin was unsuccessful, please try again or create an account at: https://ers.cr.usgs.gov/register.")

# %%
username = "AJajodia"
token = "0m0rcKmJeF2cmRF!qXMl_beHTJ1QB2eITkJyozPuNGwX7hR86EtCCeoelC1p3Iou"

serviceUrl = "https://m2m.cr.usgs.gov/api/api/json/stable/"
login_payload = {'username' : username, 'token' : token}
    
apiKey = sendRequest(serviceUrl + "login-token", login_payload)
    
print("API Key: " + apiKey + "\n")
# Out:
# API Key: eyJjaWQiOjI3NjAzODI2LCJzIjoiMTc1MTkyMjgwMSIsInIiOjYxNywicCI6WyJ1c2VyIiwiZG93bmxvYWQiLCJvcmRlciJdfQ==

# %%
def create_search_payload(datasetName, metadataFilter, acquisitionFilter):
    # create search payload from input filters
    search_payload = {
        'maxResults': 10,
        'datasetName' : datasetName,
        'sceneFilter' : {
            'metadataFilter': metadataFilter,
            'acquisitionFilter' : acquisitionFilter,
            'cloudCoverFilter' : {'min' : 0, 'max' : 50}
        }
    }
    return search_payload

# %%
sendRequest(serviceUrl + 'dataset-filters', {'datasetName': 'NAIP'}, apiKey)
# Out:
# [{'id': '5e83a340a3131f87',
#   'legacyFieldId': 25508,
#   'dictionaryLink': 'https://www.usgs.gov/centers/eros/science/national-agriculture-imagery-program-naip-data-dictionary#naip_entity_id',
#   'fieldConfig': {'type': 'Text',
#    'filters': [{'type': 'StringToUpper', 'options': {}},
#     {'type': 'Application\\Filter\\Like', 'options': {}}],
#    'options': {'size': '30'},
#    'validators': [],
#    'displayListId': ''},
#   'fieldLabel': 'Entity ID',
#   'searchSql': 'naip_entity_id like ?'},
#  {'id': '63487da1fffd134b',
#   'legacyFieldId': None,
#   'dictionaryLink': 'https://www.usgs.gov/centers/eros/science/national-agriculture-imagery-program-naip-data-dictionary#project_name',
#   'fieldConfig': {'type': 'Text',
#    'filters': [],
#    'options': {'size': '100'},
#    'validators': [],
#    'displayListId': ''},
#   'fieldLabel': 'Project',
#   'searchSql': 'PROJECT_NAME like ?'},
#  {'id': '5e83a340bf1e1ee9',
#   'legacyFieldId': 25510,
#   'dictionaryLink': 'https://www.usgs.gov/centers/eros/science/national-agriculture-imagery-program-naip-data-dictionary#state',
#   'fieldConfig': {'type': 'Select',
#    'filters': [{'type': 'StringToUpper', 'options': {}},
#     {'type': 'Application\\Filter\\Like', 'options': {}}],
#    'options': {'size': '5', 'multiple': 'true'},
#    'validators': [],
#    'displayListId': '673'},
#   'fieldLabel': 'State',
#   'searchSql': 'STATE like ?',
#   'valueList': {'': 'All                              ',
#    '%AL%': 'ALABAMA',
#    '%AK%': 'ALASKA',
#    '%AR%': 'ARKANSAS',
#    '%AZ%': 'ARIZONA',
#    'CA': 'CALIFORNIA',
#    '%CO%': 'COLORADO',
#    '%CT%': 'CONNECTICUT',
#    'DE': 'DELAWARE',
#    'DC': 'DISTRICT OF COLUMBIA',
#    '%FL%': 'FLORIDA',
#    '%GA%': 'GEORGIA',
#    '%HI%': 'HAWAII',
#    '%ID%': 'IDAHO',
#    '%IL%': 'ILLINOIS',
#    '%IN%': 'INDIANA',
#    '%IA%': 'IOWA',
#    '%KS%': 'KANSAS',
#    '%KY%': 'KENTUCKY',
#    '%LA%': 'LOUISIANA',
#    '%ME%': 'MAINE',
#    '%MD%': 'MARYLAND',
#    '%MA%': 'MASSACHUSETTS',
#    '%MI%': 'MICHIGAN',
#    '%MN%': 'MINNESOTA',
#    '%MS%': 'MISSISSIPPI',
#    '%MO%': 'MISSOURI',
#    '%MT%': 'MONTANA',
#    '%NE%': 'NEBRASKA',
#    '%NV%': 'NEVADA',
#    '%NH%': 'NEW HAMPSHIRE',
#    '%NJ%': 'NEW JERSEY',
#    '%NM%': 'NEW MEXICO',
#    '%NY%': 'NEW YORK',
#    '%NC%': 'NORTH CAROLINA',
#    '%ND%': 'NORTH DAKOTA',
#    '%OH%': 'OHIO',
#    '%OK%': 'OKLAHOMA',
#    '%OR%': 'OREGON',
#    '%PA%': 'PENNSYLVANIA',
#    '%PR%': 'PUERTO RICO',
#    '%RI%': 'RHODE ISLAND',
#    '%SC%': 'SOUTH CAROLINA',
#    '%SD%': 'SOUTH DAKOTA',
#    '%TN%': 'TENNESSEE',
#    '%TX%': 'TEXAS',
#    '%UT%': 'UTAH',
#    '%VT%': 'VERMONT',
#    '%VA%': 'VIRGINIA',
#    '%WA%': 'WASHINGTON',
#    '%WV%': 'WEST VIRGINIA',
#    '%WI%': 'WISCONSIN',
#    '%WY%': 'WYOMING'}},
#  {'id': '5e83a3401e7ca6fd',
#   'legacyFieldId': 25511,
#   'dictionaryLink': 'https://www.usgs.gov/centers/eros/science/national-agriculture-imagery-program-naip-data-dictionary#sensor_type',
#   'fieldConfig': {'type': 'Select',
#    'filters': [],
#    'options': {'size': '4', 'multiple': 'true'},
#    'validators': [],
#    'displayListId': '2785'},
#   'fieldLabel': 'Image Type',
#   'searchSql': 'SENSOR_TYPE = ?',
#   'valueList': {'': 'All Sensor Types',
#    'CNIR': 'Color Near Infrared (CNIR)',
#    'CLR': 'Natural Color (CLR)'}},
#  {'id': '605230c496940648',
#   'legacyFieldId': None,
#   'dictionaryLink': 'https://www.usgs.gov/centers/eros/science/national-agriculture-imagery-program-naip-data-dictionary#jp2_available',
#   'fieldConfig': {'type': 'Select',
#    'filters': [],
#    'options': {'size ': '4', 'multiple': 'true'},
#    'validators': [],
#    'displayListId': '2890'},
#   'fieldLabel': 'JPG2000 Available',
#   'searchSql': 'JP2_AVAIlABLE = ?',
#   'valueList': {'Y': 'Yes', 'N': 'No'}},
#  {'id': '62a87101c2b8abd4',
#   'legacyFieldId': None,
#   'dictionaryLink': 'https://www.usgs.gov/centers/eros/science/national-agriculture-imagery-program-naip-data-dictionary#resolution',
#   'fieldConfig': {'type': 'Select',
#    'filters': [],
#    'options': {'size': '5'},
#    'validators': [],
#    'displayListId': '62d01f8427516fba'},
#   'fieldLabel': 'Resolution',
#   'searchSql': 'RESOLUTION = ?',
#   'valueList': {'1.00': '1.0  Meter',
#    '0.60': '0.6  Meter',
#    '0.50': '0.5  Meter',
#    '0.30': '0.3  Meter'}},
#  {'id': '673f89a4f0b5ba48',
#   'legacyFieldId': None,
#   'dictionaryLink': 'https://www.usgs.gov/centers/eros/science/national-agriculture-imagery-program-naip-data-dictionary#date_entered',
#   'fieldConfig': {'type': 'Range',
#    'filters': [],
#    'options': {},
#    'validators': [],
#    'displayListId': ''},
#   'fieldLabel': 'Date Entered (YYYY-MM-DD)',
#   'searchSql': 'date_entered between ?'}]

# %%
payload = {'datasetName' : 'NAIP',
           'sceneFilter': {'metadataFilter': {'filterType': 'and', 'childFilters': [{'filterType': 'value',
                                'filterId': '62a87101c2b8abd4',
                                'value': '1.00'}, {'filterType': 'value',
                                'filterId': '5e83a340bf1e1ee9',
                                'value': '%FL%'}]}}, 'maxResults': 50,
            'spatialFilter' : {'filterType' : "mbr",
                      'lowerLeft' : {'latitude' : 25.3, 'longitude' : -80.9},
                      'upperRight' : { 'latitude' : 25.5, 'longitude' : -81.1}}}

scenes = sendRequest(serviceUrl + 'scene-search', payload, apiKey)

# %%
sceneIds = []
for result in scenes['results']:
    # Add this scene to the list I would like to download
    sceneIds.append(result['entityId'])

# %%
sceneIds
# Out:
# ['2545639',
#  '2545641',
#  '2545643',
#  '2545644',
#  '2545645',
#  '2545646',
#  '2545647',
#  '2545648',
#  '2545649',
#  '2545650',
#  '2545651',
#  '2545652',
#  '2545653',
#  '2545654',
#  '2545663',
#  '2545665',
#  '2545667',
#  '2545668',
#  '2545669',
#  '2545670',
#  '2545671',
#  '2545684',
#  '2545686',
#  '2545687',
#  '2545690',
#  '2545691',
#  '2545695',
#  '2545696',
#  '2545697',
#  '2545698',
#  '2545699',
#  '2545700',
#  '2545701',
#  '2545702',
#  '2545703',
#  '2545704',
#  '2545705',
#  '2545706',
#  '2545707',
#  '2545720',
#  '2545722',
#  '2545724',
#  '2545725',
#  '2545726',
#  '2545727',
#  '2545739',
#  '2545741',
#  '2545743',
#  '2545744',
#  '2545745']

# %%
def downloadFile(url):
    sema.acquire()
    global path
    try:        
        response = requests.get(url, stream=True)
        disposition = response.headers['content-disposition']
        filename = re.findall("filename=(.+)", disposition)[0].strip("\"")
        print(f"Downloading {filename} ...\n")
        if path != "" and path[-1] != "/":
            filename = "/" + filename
        open(path + filename, 'wb').write(response.content)
        print(f"Downloaded {filename}\n")
        sema.release()
    except Exception as e:
        print(f"Failed to download from {url}. {e}. Will try to re-download.")
        sema.release()
        runDownload(threads, url)
    
def runDownload(threads, url):
    thread = threading.Thread(target=downloadFile, args=(url,))
    threads.append(thread)
    thread.start()

# %%
payload = {'datasetName' : 'NAIP', 'entityIds' : sceneIds}
                                
downloadOptions = sendRequest(serviceUrl + "download-options", payload, apiKey)

# %%
downloads = []
for product in downloadOptions:
        # Make sure the product is available for this scene
        if product['available'] == True and product['productName'] == 'Full Resolution':
                downloads.append({'entityId' : product['entityId'],
                                'productId' : product['id']})

# %%
payload = {'downloads' : downloads,'label' : label}
requestResults = sendRequest(serviceUrl + "download-request", payload, apiKey)

# %%
requestResults
# Out:
# {'availableDownloads': [{'downloadId': 831819780,
#    'eulaCode': None,
#    'entityId': '2545724',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5NzgwLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1188398705}]},
#   {'downloadId': 831819781,
#    'eulaCode': None,
#    'entityId': '2545725',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5NzgxLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3743789318}]},
#   {'downloadId': 831819782,
#    'eulaCode': None,
#    'entityId': '2545726',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5NzgyLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2505800369}]},
#   {'downloadId': 831819783,
#    'eulaCode': None,
#    'entityId': '2545727',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5NzgzLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3784861203}]},
#   {'downloadId': 831819785,
#    'eulaCode': None,
#    'entityId': '2545663',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzg1LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3125549978}]},
#   {'downloadId': 831819786,
#    'eulaCode': None,
#    'entityId': '2545665',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzg2LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1660816635}]},
#   {'downloadId': 831819787,
#    'eulaCode': None,
#    'entityId': '2545667',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzg3LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3227565715}]},
#   {'downloadId': 831819788,
#    'eulaCode': None,
#    'entityId': '2545668',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzg4LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3476753477}]},
#   {'downloadId': 831819790,
#    'eulaCode': None,
#    'entityId': '2545669',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5NzkwLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 885096259}]},
#   {'downloadId': 831819791,
#    'eulaCode': None,
#    'entityId': '2545670',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5NzkxLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2261407896}]},
#   {'downloadId': 831819792,
#    'eulaCode': None,
#    'entityId': '2545690',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5NzkyLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3276034809}]},
#   {'downloadId': 831819794,
#    'eulaCode': None,
#    'entityId': '2545745',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzk0LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 421824910}]},
#   {'downloadId': 831819795,
#    'eulaCode': None,
#    'entityId': '2545691',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzk1LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2889874109}]},
#   {'downloadId': 831819796,
#    'eulaCode': None,
#    'entityId': '2545671',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzk2LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3466027727}]},
#   {'downloadId': 831819797,
#    'eulaCode': None,
#    'entityId': '2545684',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzk3LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2314422199}]},
#   {'downloadId': 831819799,
#    'eulaCode': None,
#    'entityId': '2545686',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5Nzk5LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2314939894}]},
#   {'downloadId': 831819800,
#    'eulaCode': None,
#    'entityId': '2545639',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODAwLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1861865451}]},
#   {'downloadId': 831819801,
#    'eulaCode': None,
#    'entityId': '2545641',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODAxLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2998402995}]},
#   {'downloadId': 831819802,
#    'eulaCode': None,
#    'entityId': '2545643',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODAyLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 4271792100}]},
#   {'downloadId': 831819804,
#    'eulaCode': None,
#    'entityId': '2545644',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODA0LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2506815267}]},
#   {'downloadId': 831819805,
#    'eulaCode': None,
#    'entityId': '2545645',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODA1LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1093008053}]},
#   {'downloadId': 831819806,
#    'eulaCode': None,
#    'entityId': '2545646',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODA2LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 4199779438}]},
#   {'downloadId': 831819807,
#    'eulaCode': None,
#    'entityId': '2545647',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODA3LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1138425865}]},
#   {'downloadId': 831819809,
#    'eulaCode': None,
#    'entityId': '2545648',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODA5LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 671589613}]},
#   {'downloadId': 831819810,
#    'eulaCode': None,
#    'entityId': '2545649',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODEwLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2633437414}]},
#   {'downloadId': 831819811,
#    'eulaCode': None,
#    'entityId': '2545650',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODExLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 187392988}]},
#   {'downloadId': 831819813,
#    'eulaCode': None,
#    'entityId': '2545651',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODEzLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1809253973}]},
#   {'downloadId': 831819814,
#    'eulaCode': None,
#    'entityId': '2545652',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODE0LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1016508450}]},
#   {'downloadId': 831819815,
#    'eulaCode': None,
#    'entityId': '2545653',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODE1LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1884117678}]},
#   {'downloadId': 831819816,
#    'eulaCode': None,
#    'entityId': '2545654',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODE2LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3336947826}]},
#   {'downloadId': 831819818,
#    'eulaCode': None,
#    'entityId': '2545739',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODE4LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 1407811975}]},
#   {'downloadId': 831819819,
#    'eulaCode': None,
#    'entityId': '2545741',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODE5LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2098426477}]},
#   {'downloadId': 831819820,
#    'eulaCode': None,
#    'entityId': '2545743',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODIwLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2067347258}]},
#   {'downloadId': 831819821,
#    'eulaCode': None,
#    'entityId': '2545744',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODIxLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2530587574}]},
#   {'downloadId': 831819822,
#    'eulaCode': None,
#    'entityId': '2545695',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODIyLCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2861974561}]},
#   {'downloadId': 831819824,
#    'eulaCode': None,
#    'entityId': '2545696',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODI0LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3435548224}]},
#   {'downloadId': 831819825,
#    'eulaCode': None,
#    'entityId': '2545697',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODI1LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 387816321}]},
#   {'downloadId': 831819826,
#    'eulaCode': None,
#    'entityId': '2545698',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODI2LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2869122639}]},
#   {'downloadId': 831819827,
#    'eulaCode': None,
#    'entityId': '2545699',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODI3LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 3415648681}]},
#   {'downloadId': 831819829,
#    'eulaCode': None,
#    'entityId': '2545700',
#    'url': 'https://dds.cr.usgs.gov/download/eyJpZCI6ODMxODE5ODI5LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value':
CJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 46575348}]},
#   {'downloadId': 831841249,
#    'eulaCode': None,
#    'entityId': '2545722',
#    'url': 'https://dds.cr.usgs.gov/download-staging/eyJpZCI6ODMxODQxMjQ5LCJjb250YWN0SWQiOjI3NjAzODI2fQ==',
#    'checksum_values': [{'id': 'cksum', 'value': 2484048509}]}],
#  'failed': [],
#  'newRecords': {'831841246': '20250707_141320',
#   '831841247': '20250707_141320',
#   '831841248': '20250707_141320',
#   '831841249': '20250707_141320'},
#  'remainingLimits': [{'limitType': 'user',
#    'username': 'AJajodia',
#    'recentDownloadCount': 14996,
#    'pendingDownloadCount': 20000,
#    'unattemptedDownloadCount': 18898},
#   {'limitType': 'ip',
#    'ipAddress': '132.239.17.123',
#    'recentDownloadCount': 14996,
#    'pendingDownloadCount': 20000,
#    'unattemptedDownloadCount': 18899}],
#  'numInvalidScenes': 0}

# %%
for download in requestResults['availableDownloads'] :
    downloadFile(download['url'])
# Out:
# Downloading m_2708013_ne_17_1_20171211.ZIP ...
#
# Downloaded /m_2708013_ne_17_1_20171211.ZIP
#
# Downloading m_2708013_nw_17_1_20171211.ZIP ...
#
# Downloaded /m_2708013_nw_17_1_20171211.ZIP
#
# Downloading m_2708013_se_17_1_20171211.ZIP ...
#
# Downloaded /m_2708013_se_17_1_20171211.ZIP
#
# Downloading m_2708013_sw_17_1_20171211.ZIP ...
#
# Downloaded /m_2708013_sw_17_1_20171211.ZIP
#
# Downloading m_2708028_ne_17_1_20171211.ZIP ...
#
# Downloaded /m_2708028_ne_17_1_20171211.ZIP
#
# Downloading m_2708028_se_17_1_20171211.ZIP ...
#
# Downloaded /m_2708028_se_17_1_20171211.ZIP
#
# Downloading m_2708029_ne_17_1_20171211.ZIP ...
#
# Downloaded /m_2708029_ne_17_1_20171211.ZIP
#
# Downloading m_2708029_nw_17_1_20171211.ZIP ...
#
# Downloaded /m_2708029_nw_17_1_20171211.ZIP
#
# Downloading m_2708029_se_17_1_20171211.ZIP ...
#
# Downloaded /m_2708029_se_17_1_20171211.ZIP
#
# Downloading m_2708029_sw_17_1_20171211.ZIP ...
#
# Downloaded /m_2708029_sw_17_1_20171211.ZIP
#
# Downloading m_2708030_nw_17_1_20171211.ZIP ...
#
# Downloaded /m_2708030_nw_17_1_20171211.ZIP
#
# Downloading m_2708030_se_17_1_20171211.ZIP ...
#
# Downloaded /m_2708030_se_17_1_20171211.ZIP
#
# Downloading m_2708038_se_17_1_20171211.ZIP ...
#
# Downloaded /m_2708038_se_17_1_20171211.ZIP
#
# Downloading m_2708038_sw_17_1_20171211.ZIP ...
#
# Downloaded /m_2708038_sw_17_1_20171211.ZIP
#
# Downloading m_2708044_ne_17_1_20171211.ZIP ...
#
# Downloaded /m_2708044_ne_17_1_20171211.ZIP
#
# Downloading m_2708044_se_17_1_20171211.ZIP ...
#
# Downloaded /m_2708044_se_17_1_20171211.ZIP
#
# Downloading m_2708052_ne_17_1_20171211.ZIP ...
#
# Downloaded /m_2708052_ne_17_1_20171211.ZIP
#
# Downloading m_2708052_se_17_1_20171211.ZIP ...
#
# Downloaded /m_2708052_se_17_1_20171211.ZIP
#
# Downloading m_2708053_ne_17_1_20171211.ZIP ...
#
# Downloaded /m_2708053_ne_17_1_20171211.ZIP
#
# Downloading m_2708053_nw_17_1_20171211.ZIP ...
#
# Downloaded /m_2708053_nw_17_1_20171211.ZIP
#
# Downloading m_2708053_se_17_1_20171211.ZIP ...
